# %% [markdown]
# # TASK 1
#
# Link to the data file: Record Matching Data File
#
# Description
# There are 2 datasets present in the file. Data 1 and Data 2
# The primary key for both data1 and data2 is Order Id + Product ID combination (i.e. the individual datasets do not have any duplicate on this combination)
#
# Provide solution and approach for the following:
# How to identify the Records (Order ID + Product ID combination) present in data1 but missing in data2 (Specify the number of records missing in your answer)
# How to identify the Records (Order ID + Product ID combination) missing in data1 but present in data2 (Specify the number of records missing in your answer)
# Find the Sum of the total Qty of Records missing in data1 but present in data2
# Find the total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2
#
# Allowed Tools: Excel, R, Python, SQL

# %%
import pandas as pd
import numpy as np

# %%
d1_rg=pd.read_csv('data1.csv')
d1_rg
# Out:
#             Order ID       Product ID  Qty
# 0     CA-2014-100090  FUR-TA-10003715    3
# 1     CA-2014-100090  OFF-BI-10001597    6
# 2     CA-2014-100293  OFF-PA-10000176    6
# 3     CA-2014-100328  OFF-BI-10000343    1
# 4     CA-2014-100363  OFF-FA-10000611    2
# ...              ...              ...  ...
# 9472  US-2017-169551  OFF-PA-10004100    3
# 9473  US-2017-169551  OFF-ST-10004835    3
# 9474  US-2017-169551  TEC-AC-10002018    3
# 9475  US-2017-169551  TEC-AC-10003033    2
# 9476  US-2017-169551  TEC-PH-10001363    2
#
# [9477 rows x 3 columns]

# %%
d1_rg.size
# Out:
# 28431

# %%
d1_rg.shape
# Out:
# (9477, 3)

# %%
d1_rg['Data1_Primary_key']=d1_rg['Order ID']+d1_rg['Product ID']
d1_rg
# Out:
#             Order ID       Product ID  Qty              Data1_Primary_key
# 0     CA-2014-100090  FUR-TA-10003715    3  CA-2014-100090FUR-TA-10003715
# 1     CA-2014-100090  OFF-BI-10001597    6  CA-2014-100090OFF-BI-10001597
# 2     CA-2014-100293  OFF-PA-10000176    6  CA-2014-100293OFF-PA-10000176
# 3     CA-2014-100328  OFF-BI-10000343    1  CA-2014-100328OFF-BI-10000343
# 4     CA-2014-100363  OFF-FA-10000611    2  CA-2014-100363OFF-FA-10000611
# ...              ...              ...  ...                            ...
# 9472  US-2017-169551  OFF-PA-10004100    3  US-2017-169551OFF-PA-10004100
# 9473  US-2017-169551  OFF-ST-10004835    3  US-2017-169551OFF-ST-10004835
# 9474  US-2017-169551  TEC-AC-10002018    3  US-2017-169551TEC-AC-10002018
# 9475  US-2017-169551  TEC-AC-10003033    2  US-2017-169551TEC-AC-10003033
# 9476  US-2017-169551  TEC-PH-10001363    2  US-2017-169551TEC-PH-10001363
#
# [9477 rows x 4 columns]

# %%
d1_rg.size
# Out:
# 37908

# %%
d1_rg.shape
# Out:
# (9477, 4)

# %%
d2_rg=pd.read_csv('data2.csv')
d2_rg
# Out:
#             Order ID       Product ID  Qty
# 0     CA-2014-100090  FUR-TA-10003715    3
# 1     CA-2014-100090  OFF-BI-10001597    6
# 2     CA-2014-100293  OFF-PA-10000176    6
# 3     CA-2014-100328  OFF-BI-10000343    1
# 4     CA-2014-100363  OFF-FA-10000611    2
# ...              ...              ...  ...
# 9474  US-2017-169551  OFF-PA-10004100    3
# 9475  US-2017-169551  OFF-ST-10004835    3
# 9476  US-2017-169551  TEC-AC-10002018    3
# 9477  US-2017-169551  TEC-AC-10003033    2
# 9478  US-2017-169551  TEC-PH-10001363    2
#
# [9479 rows x 3 columns]

# %%
d2_rg.size
# Out:
# 28437

# %%
d2_rg.shape
# Out:
# (9479, 3)

# %%
d2_rg['Data2_Primary_key']=d2_rg['Order ID']+d2_rg['Product ID']
d2_rg
# Out:
#             Order ID       Product ID  Qty              Data2_Primary_key
# 0     CA-2014-100090  FUR-TA-10003715    3  CA-2014-100090FUR-TA-10003715
# 1     CA-2014-100090  OFF-BI-10001597    6  CA-2014-100090OFF-BI-10001597
# 2     CA-2014-100293  OFF-PA-10000176    6  CA-2014-100293OFF-PA-10000176
# 3     CA-2014-100328  OFF-BI-10000343    1  CA-2014-100328OFF-BI-10000343
# 4     CA-2014-100363  OFF-FA-10000611    2  CA-2014-100363OFF-FA-10000611
# ...              ...              ...  ...                            ...
# 9474  US-2017-169551  OFF-PA-10004100    3  US-2017-169551OFF-PA-10004100
# 9475  US-2017-169551  OFF-ST-10004835    3  US-2017-169551OFF-ST-10004835
# 9476  US-2017-169551  TEC-AC-10002018    3  US-2017-169551TEC-AC-10002018
# 9477  US-2017-169551  TEC-AC-10003033    2  US-2017-169551TEC-AC-10003033
# 9478  US-2017-169551  TEC-PH-10001363    2  US-2017-169551TEC-PH-10001363
#
# [9479 rows x 4 columns]

# %%
d2_rg.size
# Out:
# 37916

# %%
d2_rg.shape
# Out:
# (9479, 4)

# %%
new_data_rg=d1_rg.merge(d2_rg, how='outer', left_on=['Data1_Primary_key'], right_on=['Data2_Primary_key'])
new_data_rg
# Out:
#           Order ID_x     Product ID_x  Qty_x              Data1_Primary_key  \
# 0     CA-2014-100090  FUR-TA-10003715    3.0  CA-2014-100090FUR-TA-10003715
# 1     CA-2014-100090  OFF-BI-10001597    6.0  CA-2014-100090OFF-BI-10001597
# 2     CA-2014-100293  OFF-PA-10000176    6.0  CA-2014-100293OFF-PA-10000176
# 3     CA-2014-100328  OFF-BI-10000343    1.0  CA-2014-100328OFF-BI-10000343
# 4     CA-2014-100363  OFF-FA-10000611    2.0  CA-2014-100363OFF-FA-10000611
# ...              ...              ...    ...                            ...
# 9980             NaN              NaN    NaN                            NaN
# 9981             NaN              NaN    NaN                            NaN
# 9982             NaN              NaN    NaN                            NaN
# 9983             NaN              NaN    NaN                            NaN
# 9984             NaN              NaN    NaN                            NaN
#
#           Order ID_y     Product ID_y  Qty_y              Data2_Primary_key
# 0     CA-2014-100090  FUR-TA-10003715    3.0  CA-2014-100090FUR-TA-10003715
# 1     CA-2014-100090  OFF-BI-10001597    6.0  CA-2014-100090OFF-BI-10001597
# 2     CA-2014-100293  OFF-PA-10000176    6.0  CA-2014-100293OFF-PA-10000176
# 3     CA-2014-100328  OFF-BI-10000343    1.0  CA-2014-100328OFF-BI-10000343
# 4     CA-2014-100363  OFF-FA-10000611    2.0  CA-2014-100363OFF-FA-10000611
# ...              ...              ...    ...                            ...
# 9980  US-2017-165344  OFF-BI-10003196   10.0  US-2017-165344OFF-BI-10003196
# 9981  US-2017-165358  TEC-CO-10001943    5.0  US-2017-165358TEC-CO-10001943
# 9982  US-2017-167920  OFF-AP-10000159    5.0  US-2017-167920OFF-AP-10000159
# 9983  US-2017-169502  OFF-AP-10001947    5.0  US-2017-169502OFF-AP-10001947
# 9984  US-2017-169551  FUR-BO-10001519    3.0  US-2017-169551FUR-BO-10001519
#
# [9985 rows x 8 columns]

# %%
new_data_rg.size
# Out:
# 79880

# %%
new_data_rg.shape
# Out:
# (9985, 8)

# %% [markdown]
# # 1.
# How to identify the Records (Order ID + Product ID combination) present in data1 but missing in data2 (Specify the number of records missing in your answer)

# %%
present_data1_missing_data2=new_data_rg[new_data_rg['Data2_Primary_key'].isna()]
present_data1_missing_data2
# Out:
#           Order ID_x     Product ID_x  Qty_x              Data1_Primary_key  \
# 9     CA-2014-100678  OFF-EN-10000056    3.0  CA-2014-100678OFF-EN-10000056
# 18    CA-2014-100895  OFF-AR-10004511    2.0  CA-2014-100895OFF-AR-10004511
# 34    CA-2014-101560  OFF-BI-10000309    3.0  CA-2014-101560OFF-BI-10000309
# 60    CA-2014-102673  OFF-LA-10001771   12.0  CA-2014-102673OFF-LA-10001771
# 84    CA-2014-103366  TEC-AC-10003628    5.0  CA-2014-103366TEC-AC-10003628
# ...              ...              ...    ...                            ...
# 9389  US-2017-160836  OFF-AP-10001626    2.0  US-2017-160836OFF-AP-10001626
# 9402  US-2017-162558  FUR-FU-10002364    2.0  US-2017-162558FUR-FU-10002364
# 9419  US-2017-163657  OFF-BI-10000138    5.0  US-2017-163657OFF-BI-10000138
# 9426  US-2017-164056  FUR-TA-10001307    5.0  US-2017-164056FUR-TA-10001307
# 9434  US-2017-165456  FUR-CH-10003981    6.0  US-2017-165456FUR-CH-10003981
#
#      Order ID_y Product ID_y  Qty_y Data2_Primary_key
# 9           NaN          NaN    NaN               NaN
# 18          NaN          NaN    NaN               NaN
# 34          NaN          NaN    NaN               NaN
# 60          NaN          NaN    NaN               NaN
# 84          NaN          NaN    NaN               NaN
# ...         ...          ...    ...               ...
# 9389        NaN          NaN    NaN               NaN
# 9402        NaN          NaN    NaN               NaN
# 9419        NaN          NaN    NaN               NaN
# 9426        NaN          NaN    NaN               NaN
# 9434        NaN          NaN    NaN               NaN
#
# [506 rows x 8 columns]

# %%
a1=present_data1_missing_data2.shape[0]

# %%
print(f"Records(OrderID+ProductID) present in data1 but missing in data2 = {a1}")
# Out:
# Records(OrderID+ProductID) present in data1 but missing in data2 = 506

# %% [markdown]
# # 2.
# How to identify the Records (Order ID + Product ID combination) missing in data1 but present in data2 (Specify the number of records missing in your answer)

# %%
present_data2_missing_data1=new_data_rg[new_data_rg['Data1_Primary_key'].isna()]
present_data2_missing_data1
# Out:
#      Order ID_x Product ID_x  Qty_x Data1_Primary_key      Order ID_y  \
# 9477        NaN          NaN    NaN               NaN  CA-2014-100706
# 9478        NaN          NaN    NaN               NaN  CA-2014-100762
# 9479        NaN          NaN    NaN               NaN  CA-2014-101427
# 9480        NaN          NaN    NaN               NaN  CA-2014-102652
# 9481        NaN          NaN    NaN               NaN  CA-2014-102869
# ...         ...          ...    ...               ...             ...
# 9980        NaN          NaN    NaN               NaN  US-2017-165344
# 9981        NaN          NaN    NaN               NaN  US-2017-165358
# 9982        NaN          NaN    NaN               NaN  US-2017-167920
# 9983        NaN          NaN    NaN               NaN  US-2017-169502
# 9984        NaN          NaN    NaN               NaN  US-2017-169551
#
#          Product ID_y  Qty_y              Data2_Primary_key
# 9477  TEC-AC-10001314    2.0  CA-2014-100706TEC-AC-10001314
# 9478  OFF-PA-10001815    3.0  CA-2014-100762OFF-PA-10001815
# 9479  OFF-AR-10002257    3.0  CA-2014-101427OFF-AR-10002257
# 9480  FUR-FU-10001918    7.0  CA-2014-102652FUR-FU-10001918
# 9481  OFF-PA-10000788    3.0  CA-2014-102869OFF-PA-10000788
# ...               ...    ...                            ...
# 9980  OFF-BI-10003196   10.0  US-2017-165344OFF-BI-10003196
# 9981  TEC-CO-10001943    5.0  US-2017-165358TEC-CO-10001943
# 9982  OFF-AP-10000159    5.0  US-2017-167920OFF-AP-10000159
# 9983  OFF-AP-10001947    5.0  US-2017-169502OFF-AP-10001947
# 9984  FUR-BO-10001519    3.0  US-2017-169551FUR-BO-10001519
#
# [508 rows x 8 columns]

# %%
a2=present_data2_missing_data1.shape[0]

# %%
print(f"Records(OrderID+ProductID) missing in data1 but present in data2 = {a2}")
# Out:
# Records(OrderID+ProductID) missing in data1 but present in data2 = 508

# %% [markdown]
# # 3.
# Find the Sum of the total Qty of Records missing in data1 but present in data2

# %%
a3=int(present_data2_missing_data1['Qty_y'].sum())

# %%
print(f"Sum of the total Qty of Records missing in data1 but present in data2 = {a3}")
# Out:
# Sum of the total Qty of Records missing in data1 but present in data2 = 1956

# %% [markdown]
# # 4.
# Find the total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2

# %%
a4=new_data_rg.shape[0]

# %%
print(f"The total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2 = {a4}")
# Out:
# The total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2 = 9985
